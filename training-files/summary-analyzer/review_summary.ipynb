# %%
import pandas as pd
df=pd.read_csv('d.csv')

# %%
df.head(16)
# Out:
#     Unnamed: 0                                       product_name  \
# 0            0  Alex Vando Mens Dress Shirts Regular Fit Long ...
# 1            0  Unlisted by Kenneth Cole Men's Dress Shirt Sli...
# 2            0  Kenneth Cole Unlisted Men's Dress Shirt Slim F...
# 3            0  Van Heusen Men's Dress Shirt Regular Fit Popli...
# 4            0  Amazon Essentials Men's Slim-Fit Wrinkle-Resis...
# 5            0   Van Heusen Men's Dress Shirt Fitted Poplin Solid
# 6            0  Amazon Essentials Men's Standard Regular-fit L...
# 7            0  Allsense Men's Long Sleeve Regular Fit Dress S...
# 8            0  Van Heusen Men's Dress Shirt Regular Fit Oxfor...
# 9            0  Van Heusen Men's Dress Shirt Flex Regular Fit ...
# 10           0  FLY HAWK Mens Fiber Casual Button Up Slim Fit ...
# 11           0  Kenneth Cole Unlisted Men's Dress Shirt Big an...
# 12           0  Van Heusen Men's BIG FIT Dress Shirts Flex Col...
# 13           0  Van Heusen Men's Dress Shirt Regular Fit Pinpo...
# 14           0  Arrow 1851 Men's Dress Shirt Poplin (Available...
#
#                                               reviews
# 0   [{'review_heading': 'Very pleasantly surprised...
# 1   [{'review_heading': 'Thumbs Up', 'text_review'...
# 2   [{'review_heading': 'Very Thin Material -- See...
# 3   [{'review_heading': 'Mediocre in Every Aspect....
# 4   [{'review_heading': "Hardly 'Skinny' at all- t...
# 5   [{'review_heading': 'Sleeve Length is terribly...
# 6   [{'review_heading': 'Before you buy', 'text_re...
# 7   [{'review_heading': 'Beautiful color!!', 'text...
# 8   [{'review_heading': 'Not sure I can trust the ...
# 9   [{'review_heading': 'Order your regular neck s...
# 10  [{'review_heading': 'Love it!! Must have!!', '...
# 11  [{'review_heading': 'Slightly worse fit than a...
# 12  [{'review_heading': 'Jacks Sunday white shirt ...
# 13  [{'review_heading': 'Good traditional shirt wi...
# 14  [{'review_heading': 'Great shirt for the price...

# %%
text=""

# %%
tot=15
import ast
import re
import string
f=open('z.txt','w',encoding='utf-8')
g=open('final.txt','w',encoding='utf-8')
res=[]
for i in range(tot):
    reviews=ast.literal_eval(df['reviews'][i])
    arr=[dict() for x in range(7)]
    f.write("\u0332".join(df['product_name'][i])+"\n\n\n")
    for review in reviews:
        text=review['review_heading']
        text+=review['text_review']
    import re
    import nltk
    text = re.sub(r'\[[0-9]*\]',' ',text)            
    text = re.sub(r'\s+',' ',text)    
    clean_text = text.lower()
    clean_text = re.sub(r'\W',' ',clean_text)
    clean_text = re.sub(r'\d',' ',clean_text)
    clean_text = re.sub(r'\s+',' ',clean_text)
    sentences = nltk.sent_tokenize(text)
    stop_words = nltk.corpus.stopwords.words('english')
    word2count = {}  #line 1
    for word in nltk.word_tokenize(clean_text):     #line 2
        if word not in stop_words:                  #line 3
            if word not in word2count.keys():
                word2count[word]=1
            else:
                word2count[word]+=1
    for key in word2count.keys():                   #line 4
        word2count[key]=word2count[key]/max(word2count.values())
    sent2score = {}
    for sentence in sentences:
        for word in nltk.word_tokenize(sentence.lower()):
            if word in word2count.keys():
                if len(sentence.split(' '))<30:
                    if sentence not in sent2score.keys():
                         sent2score[sentence]=word2count[word]
                    else:
                        sent2score[sentence]+=word2count[word]
    import heapq
    best_sentences = heapq.nlargest(7,sent2score,key=sent2score.get)
    tmp=""
    for sentences in best_sentences:
        f.write(sentences+'\n\n')
        tmp+=sentences+"#";
    tmpObj={
        'product':df['product_name'][i],
        'summary':tmp[:len(tmp)-1]
    }
    res.append(tmpObj)
    print(i,len(best_sentences))
    f.write("===========================================================================================================================\n\n\n\n")
g.write(str(res))
